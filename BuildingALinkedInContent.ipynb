# %% [markdown]
# <a href="https://colab.research.google.com/github/tthogho1/CompareImage/blob/main/BuildingALinkedInContent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新しいセクション

# %%
# !uv pip install google-adk --prerelease=allow
# Out:
# Using Python 3.11.12 environment at: /usr
# Resolved 78 packages in 709ms
# ⠙ Preparing packages... (0/15)
# ⠙ Preparing packages... (0/15)
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------     0 B/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------     0 B/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------     0 B/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------     0 B/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------     0 B/13.65 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------     0 B/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------ 13.65 KiB/13.65 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------     0 B/7.64 KiB
# sse-starlette ------------------------------ 9.88 KiB/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------ 13.65 KiB/13.65 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------ 7.64 KiB/7.64 KiB
# sse-starlette ------------------------------ 9.88 KiB/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------ 13.65 KiB/13.65 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------ 7.64 KiB/7.64 KiB
# sse-starlette ------------------------------ 9.88 KiB/9.88 KiB
# opentelemetry-exporter-gcp-trace ------------------------------ 13.65 KiB/13.65 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# starlette  ------------------------------ 14.89 KiB/70.35 KiB
# ⠙ Preparing packages... (0/15)
# httpx-sse  ------------------------------ 7.64 KiB/7.64 KiB
# sse-starlette ------------------------------ 9.88 KiB/9.88 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# starlette  ------------------------------ 14.89 KiB/70.35 KiB
# mcp        ------------------------------     0 B/74.29 KiB
# fastapi    ------------------------------     0 B/92.93 KiB
# google-cloud-trace ------------------------------     0 B/100.88 KiB
# ⠙ Preparing packages... (0/15)
# sse-starlette ------------------------------ 9.88 KiB/9.88 KiB
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# starlette  ------------------------------ 14.89 KiB/70.35 KiB
# mcp        ------------------------------     0 B/74.29 KiB
# fastapi    ------------------------------     0 B/92.93 KiB
# google-cloud-trace ------------------------------     0 B/100.88 KiB
# ⠙ Preparing packages... (0/15)
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# starlette  ------------------------------ 14.89 KiB/70.35 KiB
# mcp        ------------------------------     0 B/74.29 KiB
# fastapi    ------------------------------     0 B/92.93 KiB
# google-cloud-trace ------------------------------     0 B/100.88 KiB
# ⠙ Preparing packages... (0/15)
# python-dotenv ------------------------------ 14.88 KiB/19.78 KiB
# opentelemetry-resourcedetector-gcp ------------------------------ 14.89 KiB/19.90 KiB
# pydantic-settings ------------------------------ 14.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 14.89 KiB/61.02 KiB
# starlette  ------------------------------ 14.89 KiB/70.35 KiB
# mcp        ------------------------------     0 B/74.29 KiB
# fastapi    ------------------------------     0 B/92.93 KiB
# google-cloud-trace ------------------------------ 14.90 KiB/100.88 KiB
# ⠙ Preparing packages... (0/15)
# python-dotenv ------------------------------ 19.78 KiB/19.78 KiB
# pydantic-settings ------------------------------ 30.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# starlette  ------------------------------ 30.89 KiB/70.35 KiB
# mcp        ------------------------------ 14.92 KiB/74.29 KiB
# fastapi    ------------------------------ 14.91 KiB/92.93 KiB
# google-cloud-trace ------------------------------ 14.90 KiB/100.88 KiB
# google-cloud-secret-manager ------------------------------ 16.00 KiB/212.01 KiB
# authlib    ------------------------------ 14.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 16.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# pydantic-settings ------------------------------ 30.91 KiB/43.32 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# starlette  ------------------------------ 39.43 KiB/70.35 KiB
# mcp        ------------------------------ 14.92 KiB/74.29 KiB
# fastapi    ------------------------------ 14.91 KiB/92.93 KiB
# google-cloud-trace ------------------------------ 14.90 KiB/100.88 KiB
# google-cloud-secret-manager ------------------------------ 16.00 KiB/212.01 KiB
# authlib    ------------------------------ 14.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 16.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# pydantic-settings ------------------------------ 43.32 KiB/43.32 KiB
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# starlette  ------------------------------ 39.43 KiB/70.35 KiB
# mcp        ------------------------------ 14.92 KiB/74.29 KiB
# fastapi    ------------------------------ 14.91 KiB/92.93 KiB
# google-cloud-trace ------------------------------ 14.90 KiB/100.88 KiB
# google-cloud-secret-manager ------------------------------ 16.00 KiB/212.01 KiB
# authlib    ------------------------------ 14.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 16.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# uvicorn    ------------------------------ 30.89 KiB/61.02 KiB
# starlette  ------------------------------ 70.35 KiB/70.35 KiB
# mcp        ------------------------------ 30.92 KiB/74.29 KiB
# fastapi    ------------------------------ 49.14 KiB/92.93 KiB
# google-cloud-trace ------------------------------ 46.90 KiB/100.88 KiB
# google-cloud-secret-manager ------------------------------ 64.00 KiB/212.01 KiB
# authlib    ------------------------------ 14.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 50.83 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# uvicorn    ------------------------------ 46.89 KiB/61.02 KiB
# mcp        ------------------------------ 30.92 KiB/74.29 KiB
# fastapi    ------------------------------ 49.14 KiB/92.93 KiB
# google-cloud-trace ------------------------------ 46.90 KiB/100.88 KiB
# google-cloud-secret-manager ------------------------------ 64.00 KiB/212.01 KiB
# authlib    ------------------------------ 14.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 50.83 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# mcp        ------------------------------ 62.82 KiB/74.29 KiB
# fastapi    ------------------------------ 78.91 KiB/92.93 KiB
# google-cloud-trace ------------------------------ 94.90 KiB/100.88 KiB
# google-cloud-secret-manager ------------------------------ 123.34 KiB/212.01 KiB
# authlib    ------------------------------ 30.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 128.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# mcp        ------------------------------ 62.82 KiB/74.29 KiB
# fastapi    ------------------------------ 92.93 KiB/92.93 KiB
# google-cloud-trace ------------------------------ 100.88 KiB/100.88 KiB
# google-cloud-secret-manager ------------------------------ 128.00 KiB/212.01 KiB
# authlib    ------------------------------ 30.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 144.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# mcp        ------------------------------ 62.82 KiB/74.29 KiB
# fastapi    ------------------------------ 92.93 KiB/92.93 KiB
# google-cloud-secret-manager ------------------------------ 144.00 KiB/212.01 KiB
# authlib    ------------------------------ 30.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 144.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# mcp        ------------------------------ 62.82 KiB/74.29 KiB
# google-cloud-secret-manager ------------------------------ 144.00 KiB/212.01 KiB
# authlib    ------------------------------ 46.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 176.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# google-cloud-secret-manager ------------------------------ 192.00 KiB/212.01 KiB
# authlib    ------------------------------ 46.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 208.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# authlib    ------------------------------ 46.92 KiB/226.62 KiB
# google-cloud-speech ------------------------------ 224.00 KiB/326.32 KiB
# ⠙ Preparing packages... (0/15)
# authlib    ------------------------------ 62.92 KiB/226.62 KiB
# ⠙ Preparing packages... (0/15)
# ⠙ Preparing packages... (0/15)
# Prepared 15 packages in 206ms
# Installed 15 packages in 30ms
#  + authlib==1.5.2
#  + fastapi==0.115.12
#  + google-adk==0.2.0
#  + google-cloud-secret-manager==2.23.3
#  + google-cloud-speech==2.32.0
#  + google-cloud-trace==1.16.1
#  + httpx-sse==0.4.0
#  + mcp==1.6.0
#  + opentelemetry-exporter-gcp-trace==1.9.0
#  + opentelemetry-resourcedetector-gcp==1.9.0a0
#  + pydantic-settings==2.9.1
#  + python-dotenv==1.1.0
#  + sse-starlette==2.2.1
#  + starlette==0.46.2
#  + uvicorn==0.34.2

# %%
# Set Google AI Studio API key
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
GEMINI_MODEL = "gemini-2.0-flash"

# %%
from google.adk.agents.llm_agent import LlmAgent
from google.adk.tools import google_search

# Google Research Agent
google_research_agent = LlmAgent(
    name = "Google_Research_Agent",
    model = GEMINI_MODEL,
    instruction = """
    You are a Research AI agent.
    Use Google search to find recent and relevant information on the provided topic.
    Do not add information on your own apart from what you found after the Google search.
    Summarize key points, statistics, and insights in bullet points.
    """,
    description = "Researches on a given topic using Google Search.",
    tools = [google_search],
    output_key = "google_research_summary"
)

# %%
# !uv pip install -qU duckduckgo-search langchain-community --prerelease=allow

# %%
# Set up Duckduckgo search tool from Langchain

from google.adk.tools.langchain_tool import LangchainTool
from langchain_community.tools import DuckDuckGoSearchRun

# Instantiate the tool
duckduckgo_tool_instance = DuckDuckGoSearchRun(
    max_results = 5,
)

# Wrap the tool in the LangchainTool class from ADK
adk_duckduckgo_tool = LangchainTool(
    tool=duckduckgo_tool_instance,
)

# %%
# DuckDuckGo Research Agent
duckduckgo_research_agent = LlmAgent(
    name = "DuckDuckGo_Research_Agent",
    model = GEMINI_MODEL,
    instruction = """
    You are a Research AI agent.
    Use DuckDuckGo search to find recent and relevant information on the provided topic.
    Do not add information on your own apart from what you found after the DuckDuckGo search.
    Summarize key points, statistics, and insights in bullet points.
    """,
    description = "Researches on a given topic using DuckDuckGo Search.",
    tools = [adk_duckduckgo_tool],
    output_key = "duckduckgo_research_summary"
)

# %%
from google.adk.agents.parallel_agent import ParallelAgent

# Parallel Web Research Agent
parallel_web_research_agent = ParallelAgent(
    name="Parallel_Web_Research_Agent",
    sub_agents=[google_research_agent, duckduckgo_research_agent]
)

# %%
# Merge Research Agent (combine Google and DuckDuckGo results)
merge_research_agent = LlmAgent(
    name = "Merge_Research_Agent",
    model = GEMINI_MODEL,
    instruction = """
    You are a Content Merging AI.
    Merge the outputs provided by the Google and DuckDuckGo agents in the session state under the keys 'google_research_summary' and 'duckduckgo_research_summary', respectively.
    Do not add information on your own.
    Remove duplicates.
    Summarize key points clearly in bullet points.
    """,
    description = "Merges research results from Google and DuckDuckGo.",
    output_key = "merged_research_summary"
)

# %%
writer_agent = LlmAgent(
    name = "Writer_Agent",
    model = GEMINI_MODEL,
    instruction = """
    You are a LinkedIn Content Writer AI.
    Based on the research summary provided in session state with the key 'merged_research_summary', draft a LinkedIn post that includes:
    - A compelling hook and heading
    - Key insights (describing the topic in technical detail if available)
    - A clear call-to-action

    Ensure the tone is professional and engaging.
    Do not add links to any external resources.
    Do not add your own information and your writing should be totally based on the research summary.
    """,
    description = "Drafts initial LinkedIn post based on research results.",
    output_key = "initial_draft"
)

# %%
# SEO Optimizer Agent
seo_optimizer_agent = LlmAgent(
    name = "SEO_Optimizer_Agent",
    model = GEMINI_MODEL,
    instruction = """
    You are an SEO Optimizer AI.
    Enhance the draft provided in session state with the key 'initial_draft' by:
    - Incorporating relevant keywords
    - Adding appropriate hashtags (**only** 3)
    - Ensuring optimal length (not omiting relevant research details) and readability
    - Formatting for LinkedIn best practices
    """,
    description="Optimizes content for SEO and LinkedIn formatting.",
    output_key="seo_optimized_draft"
)

# %%
# Final draft guardrail

import re
import copy
from typing import Optional
from google.adk.agents.callback_context import CallbackContext
from google.adk.models import LlmResponse
from google.genai import types

def final_draft_guardrail(callback_context: CallbackContext, llm_response: LlmResponse) -> Optional[LlmResponse]:
    agent_name = callback_context.agent_name

    print(f"[Callback] Running guardrail for: {agent_name}")

    if not llm_response.content or not llm_response.content.parts:
        print("[Callback] No content found in LLM response.")
        return None

    part = llm_response.content.parts[0]

    if part.function_call or not part.text:
        print("[Callback] Skipping guardrail because response contains function call or no text.")
        return None

    original_text = part.text
    text = original_text
    modified = False

    # Remove markdown links like [text](url)
    new_text = re.sub(r'\[.*?\]\(.*?\)', '', text)

    if new_text != text:
        print("[Callback] Markdown links removed.")
        text = new_text
        modified = True

    # Remove raw URLs
    new_text = re.sub(r'https?://\S+|www\.\S+', '', text)

    if new_text != text:
        print("[Callback] Raw URLs removed.")
        text = new_text
        modified = True

    # Remove markdown formatting
    text_no_md = re.sub(r'\*\*(.*?)\*\*', r'\1', text)
    text_no_md = re.sub(r'__(.*?)__', r'\1', text_no_md)
    text_no_md = re.sub(r'\*(.*?)\*', r'\1', text_no_md)
    text_no_md = re.sub(r'_(.*?)_', r'\1', text_no_md)

    if text_no_md != text:
        print("[Callback] Markdown formatting removed.")
        text = text_no_md
        modified = True

    # Remove leftover [ ] brackets
    if '[' in text or ']' in text:
        text = text.replace('[', '').replace(']', '')
        print("[Callback] Square brackets removed.")
        modified = True

    # Replace markdown bullets with dashes
    bullet_converted = re.sub(r'^\s*\*\s+', '- ', text, flags=re.MULTILINE)

    if bullet_converted != text:
        print("[Callback] Markdown bullet points replaced with dashes.")
        text = bullet_converted
        modified = True

    # Remove intro phrases
    intro_patterns = [
        r'^\s*Here is.*?:\s*',
        r'^\s*Final draft.*?:\s*',
        r'^\s*Here\'s.*?:\s*',
        r'^\s*Your post.*?:\s*'
    ]

    for pattern in intro_patterns:
        new_text = re.sub(pattern, '', text, flags=re.IGNORECASE)

        if new_text != text:
            print(f"[Callback] Intro phrase removed using pattern: {pattern}")
            text = new_text
            modified = True

    # Extract hashtags
    hashtags = re.findall(r"#\w+", text)

    if hashtags:
        print(f"[Callback] Extracted hashtags: {hashtags}")
        modified = True

    if len(hashtags) > 3:
        print(f"[Callback] More than 3 hashtags found. Trimming to: {hashtags[:3]}")
        hashtags = hashtags[:3]

    hashtags = [tag.lower() for tag in hashtags]

    # Remove hashtags from main text
    cleaned_text = re.sub(r"#\S+", "", text)

    if cleaned_text != text:
        print("[Callback] Hashtags removed from main text.")
        text = cleaned_text
        modified = True

    if not modified:
        print("[Callback] No modifications made to the response text.")
        return None

    # Create final text
    final_text = (
        f"{text.strip()}\n\n"
        f"💡 Like this perspective? Follow Dr. Ashish Bamania to stay connected: https://www.linkedin.com/in/ashishbamania "
        f"{' '.join(hashtags)}"
    )

    print("[Callback] Final CTA and hashtags added.")

    modified_parts = [copy.deepcopy(part)]
    modified_parts[0].text = final_text.strip()

    new_response = LlmResponse(
        content=types.Content(role="model", parts=modified_parts),
        grounding_metadata=llm_response.grounding_metadata
    )

    print("[Callback] Guardrail applied successfully. Modified text returned.")

    return new_response

# %%
final_draft_writing_agent = LlmAgent(
    name = "Final_Draft_Writing_Agent",
    model = GEMINI_MODEL,
    instruction = """
    You are a LinkedIn Post Drafting AI.
    Review the optimized content provided in the session state with the key 'seo_optimized_draft' for:
    - Clarity and coherence
    - Grammatical accuracy
    - Consistent tone and style
    - Engagement and professionalism

    Remove Markdown formatting including any *.
    **Add** appropriate emojis in the post.
    Make sure only the **best 3** hastags are used.

    Provide the final version ready for posting.
    Output **only** the final LinkedIn-ready post without any introductory or explanatory text.
    **Do not** add links to any external resources.
    """,
    description = "Produces final LinkedIn post with guardrails.",
    output_key = "final_post",
    after_model_callback = final_draft_guardrail
)

# %%
# !uv pip install "crewai[tools]" --prerelease=allow
# Out:
# Using Python 3.11.12 environment at: /usr
# Resolved 199 packages in 2.28s
# ⠙ Preparing packages... (0/74)
# ⠙ Preparing packages... (0/74)
# ⠙ Preparing packages... (0/74)
# ⠙ Preparing packages... (0/74)
# ⠙ Preparing packages... (0/74)
# ⠙ Preparing packages... (0/74)
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# httptools  ------------------------------     0 B/449.01 KiB
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# pypdf      ------------------------------     0 B/295.22 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# pypdf      ------------------------------ 14.92 KiB/295.22 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# bcrypt     ------------------------------     0 B/277.50 KiB
# pypdf      ------------------------------ 14.92 KiB/295.22 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# bcrypt     ------------------------------ 14.89 KiB/277.50 KiB
# pypdf      ------------------------------ 14.92 KiB/295.22 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# gptcache   ------------------------------     0 B/128.55 KiB
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# bcrypt     ------------------------------ 14.89 KiB/277.50 KiB
# pypdf      ------------------------------ 14.92 KiB/295.22 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# gptcache   ------------------------------ 14.92 KiB/128.55 KiB
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# bcrypt     ------------------------------ 14.89 KiB/277.50 KiB
# pypdf      ------------------------------ 14.92 KiB/295.22 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# mmh3       ------------------------------     0 B/99.19 KiB
# gptcache   ------------------------------ 14.92 KiB/128.55 KiB
# alembic    ------------------------------ 77.05 KiB/226.48 KiB
# bcrypt     ------------------------------ 14.89 KiB/277.50 KiB
# pypdf      ------------------------------ 14.92 KiB/295.22 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# ⠙ Preparing packages... (0/74)
# json5      ------------------------------ 14.89 KiB/35.23 KiB
# langchain-cohere ------------------------------ 14.91 KiB/44.03 KiB
# coloredlogs ------------------------------ 14.83 KiB/44.94 KiB
# langchain-openai ------------------------------ 12.71 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 14.93 KiB/56.24 KiB
# pdfplumber ------------------------------ 14.88 KiB/58.82 KiB
# pysbd      ------------------------------ 14.84 KiB/69.42 KiB
# httpx      ------------------------------ 14.92 KiB/74.60 KiB
# mako       ------------------------------ 14.89 KiB/76.67 KiB
# instructor ------------------------------ 14.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 13.96 KiB/84.76 KiB
# posthog    ------------------------------ 14.92 KiB/87.03 KiB
# mmh3       ------------------------------ 46.92 KiB/99.19 KiB
# gptcache   ------------------------------ 14.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 14.92 KiB/133.52 KiB
# docker     ------------------------------ 16.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 14.92 KiB/206.39 KiB
# alembic    ------------------------------ 93.05 KiB/226.48 KiB
# tomli      ------------------------------ 78.89 KiB/230.50 KiB
# ⠙ Preparing packages... (0/74)
# json5      ------------------------------ 30.89 KiB/35.23 KiB
# langchain-cohere ------------------------------ 14.91 KiB/44.03 KiB
# coloredlogs ------------------------------ 30.83 KiB/44.94 KiB
# langchain-openai ------------------------------ 46.88 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 30.93 KiB/56.24 KiB
# pdfplumber ------------------------------ 14.88 KiB/58.82 KiB
# pysbd      ------------------------------ 14.84 KiB/69.42 KiB
# httpx      ------------------------------ 30.92 KiB/74.60 KiB
# mako       ------------------------------ 30.89 KiB/76.67 KiB
# instructor ------------------------------ 14.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 30.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# mmh3       ------------------------------ 94.92 KiB/99.19 KiB
# gptcache   ------------------------------ 14.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 14.92 KiB/133.52 KiB
# docker     ------------------------------ 16.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 14.92 KiB/206.39 KiB
# alembic    ------------------------------ 125.05 KiB/226.48 KiB
# tomli      ------------------------------ 155.61 KiB/230.50 KiB
# ⠙ Preparing packages... (0/74)
# json5      ------------------------------ 35.23 KiB/35.23 KiB
# langchain-cohere ------------------------------ 30.91 KiB/44.03 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langchain-openai ------------------------------ 46.88 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 46.93 KiB/56.24 KiB
# pdfplumber ------------------------------ 44.60 KiB/58.82 KiB
# pysbd      ------------------------------ 14.84 KiB/69.42 KiB
# httpx      ------------------------------ 30.92 KiB/74.60 KiB
# mako       ------------------------------ 46.89 KiB/76.67 KiB
# instructor ------------------------------ 14.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 62.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# mmh3       ------------------------------ 99.19 KiB/99.19 KiB
# gptcache   ------------------------------ 14.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 14.92 KiB/133.52 KiB
# docker     ------------------------------ 16.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 14.92 KiB/206.39 KiB
# alembic    ------------------------------ 157.05 KiB/226.48 KiB
# tomli      ------------------------------ 187.61 KiB/230.50 KiB
# ⠙ Preparing packages... (0/74)
# json5      ------------------------------ 35.23 KiB/35.23 KiB
# langchain-cohere ------------------------------ 30.91 KiB/44.03 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langchain-openai ------------------------------ 49.68 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 46.93 KiB/56.24 KiB
# pdfplumber ------------------------------ 44.60 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 46.92 KiB/74.60 KiB
# mako       ------------------------------ 46.89 KiB/76.67 KiB
# instructor ------------------------------ 14.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# gptcache   ------------------------------ 30.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 32.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 173.05 KiB/226.48 KiB
# tomli      ------------------------------ 222.89 KiB/230.50 KiB
# cohere     ------------------------------ 46.92 KiB/253.44 KiB
# ⠹ Preparing packages... (0/74)
# json5      ------------------------------ 35.23 KiB/35.23 KiB
# langchain-cohere ------------------------------ 30.91 KiB/44.03 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langchain-openai ------------------------------ 49.68 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 46.93 KiB/56.24 KiB
# pdfplumber ------------------------------ 44.60 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 62.81 KiB/74.60 KiB
# mako       ------------------------------ 62.89 KiB/76.67 KiB
# instructor ------------------------------ 14.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# gptcache   ------------------------------ 30.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 32.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 173.05 KiB/226.48 KiB
# tomli      ------------------------------ 222.89 KiB/230.50 KiB
# cohere     ------------------------------ 46.92 KiB/253.44 KiB
# ⠹ Preparing packages... (0/74)
# langchain-cohere ------------------------------ 30.91 KiB/44.03 KiB
# coloredlogs ------------------------------ 44.94 KiB/44.94 KiB
# langchain-openai ------------------------------ 49.68 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 46.93 KiB/56.24 KiB
# pdfplumber ------------------------------ 44.60 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 62.81 KiB/74.60 KiB
# mako       ------------------------------ 62.89 KiB/76.67 KiB
# instructor ------------------------------ 14.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# gptcache   ------------------------------ 30.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 32.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 173.05 KiB/226.48 KiB
# tomli      ------------------------------ 222.89 KiB/230.50 KiB
# cohere     ------------------------------ 46.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 254.89 KiB/277.50 KiB
# ⠹ Preparing packages... (0/74)
# langchain-cohere ------------------------------ 30.91 KiB/44.03 KiB
# langchain-openai ------------------------------ 49.68 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pdfplumber ------------------------------ 44.60 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 62.81 KiB/74.60 KiB
# mako       ------------------------------ 62.89 KiB/76.67 KiB
# instructor ------------------------------ 30.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# gptcache   ------------------------------ 30.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 173.05 KiB/226.48 KiB
# tomli      ------------------------------ 222.89 KiB/230.50 KiB
# cohere     ------------------------------ 62.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 270.89 KiB/277.50 KiB
# crewai     ------------------------------ 62.92 KiB/278.81 KiB
# ⠹ Preparing packages... (0/74)
# langchain-cohere ------------------------------ 30.91 KiB/44.03 KiB
# langchain-openai ------------------------------ 49.68 KiB/49.68 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pdfplumber ------------------------------ 44.60 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 62.81 KiB/74.60 KiB
# mako       ------------------------------ 62.89 KiB/76.67 KiB
# instructor ------------------------------ 30.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# gptcache   ------------------------------ 30.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 173.05 KiB/226.48 KiB
# tomli      ------------------------------ 230.50 KiB/230.50 KiB
# cohere     ------------------------------ 62.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 277.50 KiB/277.50 KiB
# crewai     ------------------------------ 62.92 KiB/278.81 KiB
# ⠹ Preparing packages... (0/74)
# langchain-cohere ------------------------------ 30.91 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 14.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pdfplumber ------------------------------ 44.60 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 62.81 KiB/74.60 KiB
# mako       ------------------------------ 62.89 KiB/76.67 KiB
# instructor ------------------------------ 30.92 KiB/83.99 KiB
# humanfriendly ------------------------------ 78.83 KiB/84.76 KiB
# posthog    ------------------------------ 46.92 KiB/87.03 KiB
# gptcache   ------------------------------ 30.92 KiB/128.55 KiB
# auth0-python ------------------------------ 14.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 173.05 KiB/226.48 KiB
# tomli      ------------------------------ 230.50 KiB/230.50 KiB
# cohere     ------------------------------ 62.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 277.50 KiB/277.50 KiB
# crewai     ------------------------------ 62.92 KiB/278.81 KiB
# pypdf      ------------------------------ 125.15 KiB/295.22 KiB
# ⠹ Preparing packages... (0/74)
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 30.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pdfplumber ------------------------------ 58.82 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 74.60 KiB/74.60 KiB
# mako       ------------------------------ 62.89 KiB/76.67 KiB
# instructor ------------------------------ 46.81 KiB/83.99 KiB
# humanfriendly ------------------------------ 84.76 KiB/84.76 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 30.92 KiB/128.55 KiB
# auth0-python ------------------------------ 30.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 189.05 KiB/226.48 KiB
# tomli      ------------------------------ 230.50 KiB/230.50 KiB
# cohere     ------------------------------ 62.92 KiB/253.44 KiB
# bcrypt     ------------------------------ 277.50 KiB/277.50 KiB
# ⠹ Preparing packages... (0/74)
# build      ------------------------------     0 B/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 30.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pdfplumber ------------------------------ 58.82 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 74.60 KiB/74.60 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# humanfriendly ------------------------------ 84.76 KiB/84.76 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 30.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 189.05 KiB/226.48 KiB
# tomli      ------------------------------ 230.50 KiB/230.50 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# ⠹ Preparing packages... (0/74)
# build      ------------------------------     0 B/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 30.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pdfplumber ------------------------------ 58.82 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 74.60 KiB/74.60 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# humanfriendly ------------------------------ 84.76 KiB/84.76 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 30.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 189.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 62.92 KiB/278.81 KiB
# ⠹ Preparing packages... (0/74)
# build      ------------------------------     0 B/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 30.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pdfplumber ------------------------------ 58.82 KiB/58.82 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 74.60 KiB/74.60 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 30.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 48.00 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 189.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 141.15 KiB/295.22 KiB
# ⠹ Preparing packages... (0/74)
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# httpx      ------------------------------ 74.60 KiB/74.60 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 30.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 189.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 141.15 KiB/295.22 KiB
# ⠹ Preparing packages... (0/74)
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 30.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 189.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 141.15 KiB/295.22 KiB
# qdrant-client ------------------------------ 94.88 KiB/299.49 KiB
# ⠹ Preparing packages... (0/74)
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pytube     ------------------------------ 56.24 KiB/56.24 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 189.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 173.26 KiB/295.22 KiB
# qdrant-client ------------------------------ 94.88 KiB/299.49 KiB
# ⠹ Preparing packages... (0/74)
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 205.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 222.89 KiB/295.22 KiB
# qdrant-client ------------------------------ 94.88 KiB/299.49 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# ⠹ Preparing packages... (0/74)
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 205.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 222.89 KiB/295.22 KiB
# qdrant-client ------------------------------ 94.88 KiB/299.49 KiB
# watchfiles ------------------------------ 424.56 KiB/444.09 KiB
# ⠸ Preparing packages... (8/74)
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# langchain-cohere ------------------------------ 44.03 KiB/44.03 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 205.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 222.89 KiB/295.22 KiB
# qdrant-client ------------------------------ 94.88 KiB/299.49 KiB
# watchfiles ------------------------------ 424.56 KiB/444.09 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/18.38 KiB
# types-requests ------------------------------     0 B/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 205.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-exporter-otlp-proto-common ------------------------------     0 B/18.38 KiB
# types-requests ------------------------------     0 B/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 14.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 205.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 30.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 30.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 205.05 KiB/226.48 KiB
# cohere     ------------------------------ 66.03 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 238.89 KiB/295.22 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 46.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 30.90 KiB/204.58 KiB
# embedchain ------------------------------ 30.92 KiB/206.39 KiB
# alembic    ------------------------------ 205.05 KiB/226.48 KiB
# cohere     ------------------------------ 78.92 KiB/253.44 KiB
# crewai     ------------------------------ 78.92 KiB/278.81 KiB
# pypdf      ------------------------------ 238.89 KiB/295.22 KiB
# ⠸ Preparing packages... (8/74)
# overrides  ------------------------------     0 B/17.41 KiB
# portalocker ------------------------------  1021 B/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# schema     ------------------------------ 6.69 KiB/18.20 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 16.00 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 46.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 62.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 30.90 KiB/204.58 KiB
# ⠸ Preparing packages... (8/74)
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# portalocker ------------------------------  1021 B/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# schema     ------------------------------ 14.88 KiB/18.20 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# build      ------------------------------ 16.00 KiB/22.41 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 46.84 KiB/69.42 KiB
# mako       ------------------------------ 76.67 KiB/76.67 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 78.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 30.92 KiB/133.52 KiB
# docker     ------------------------------ 62.03 KiB/144.31 KiB
# langchain-experimental ------------------------------ 30.90 KiB/204.58 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 16.00 KiB/16.84 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# portalocker ------------------------------ 14.91 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# schema     ------------------------------ 18.20 KiB/18.20 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 62.84 KiB/69.42 KiB
# instructor ------------------------------ 62.81 KiB/83.99 KiB
# posthog    ------------------------------ 78.92 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 46.92 KiB/132.18 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-instrumentation-fastapi ------------------------------     0 B/11.84 KiB
# backoff    ------------------------------     0 B/14.79 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 16.00 KiB/16.84 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# portalocker ------------------------------ 14.91 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# schema     ------------------------------ 18.20 KiB/18.20 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 16.00 KiB/21.07 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 62.84 KiB/69.42 KiB
# instructor ------------------------------ 78.71 KiB/83.99 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-instrumentation-fastapi ------------------------------     0 B/11.84 KiB
# backoff    ------------------------------     0 B/14.79 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 16.00 KiB/16.84 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# portalocker ------------------------------ 14.91 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 21.07 KiB/21.07 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 46.91 KiB/54.54 KiB
# pysbd      ------------------------------ 62.84 KiB/69.42 KiB
# instructor ------------------------------ 78.71 KiB/83.99 KiB
# posthog    ------------------------------ 87.03 KiB/87.03 KiB
# ⠸ Preparing packages... (8/74)
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 14.89 KiB/15.95 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 16.00 KiB/16.84 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# portalocker ------------------------------ 14.91 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 21.07 KiB/21.07 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# opentelemetry-proto ------------------------------ 54.54 KiB/54.54 KiB
# pysbd      ------------------------------ 62.84 KiB/69.42 KiB
# instructor ------------------------------ 78.71 KiB/83.99 KiB
# posthog    ------------------------------ 87.03 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# ⠸ Preparing packages... (8/74)
# deprecation ------------------------------     0 B/10.92 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# opentelemetry-instrumentation-asgi ------------------------------ 15.95 KiB/15.95 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 16.00 KiB/16.84 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# portalocker ------------------------------ 14.91 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 21.07 KiB/21.07 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# pysbd      ------------------------------ 62.84 KiB/69.42 KiB
# instructor ------------------------------ 78.71 KiB/83.99 KiB
# posthog    ------------------------------ 87.03 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# ⠸ Preparing packages... (8/74)
# deprecation ------------------------------     0 B/10.92 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 16.00 KiB/16.84 KiB
# overrides  ------------------------------ 14.88 KiB/17.41 KiB
# portalocker ------------------------------ 14.91 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 14.87 KiB/20.18 KiB
# json-repair ------------------------------ 21.07 KiB/21.07 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# pysbd      ------------------------------ 62.84 KiB/69.42 KiB
# instructor ------------------------------ 78.71 KiB/83.99 KiB
# posthog    ------------------------------ 87.03 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 62.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 47.22 KiB/133.52 KiB
# ⠸ Preparing packages... (8/74)
# deprecation ------------------------------ 10.92 KiB/10.92 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# opentelemetry-exporter-otlp-proto-http ------------------------------ 16.00 KiB/16.84 KiB
# overrides  ------------------------------ 17.41 KiB/17.41 KiB
# portalocker ------------------------------ 17.99 KiB/17.99 KiB
# opentelemetry-exporter-otlp-proto-grpc ------------------------------ 14.89 KiB/18.16 KiB
# opentelemetry-exporter-otlp-proto-common ------------------------------ 14.89 KiB/18.38 KiB
# types-requests ------------------------------ 20.18 KiB/20.18 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# opentelemetry-instrumentation ------------------------------ 30.09 KiB/30.09 KiB
# pysbd      ------------------------------ 62.84 KiB/69.42 KiB
# instructor ------------------------------ 78.71 KiB/83.99 KiB
# posthog    ------------------------------ 87.03 KiB/87.03 KiB
# gptcache   ------------------------------ 46.92 KiB/128.55 KiB
# auth0-python ------------------------------ 62.92 KiB/132.18 KiB
# mem0ai     ------------------------------ 47.22 KiB/133.52 KiB
# docker     ------------------------------ 94.03 KiB/144.31 KiB
# ⠸ Preparing packages... (8/74)
# deprecation ------------------------------ 10.92 KiB/10.92 KiB
# opentelemetry-instrumentation-fastapi ------------------------------ 11.84 KiB/11.84 KiB
# backoff    ------------------------------ 14.79 KiB/14.79 KiB
# ...
# jedi       ------------------------------ 456.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.31 MiB/1.90 MiB
# pypdfium2  ------------------------------ 1.00 MiB/2.74 MiB
# pyright    ------------------------------ 2.17 MiB/5.33 MiB
# pdfminer-six ------------------------------ 5.18 MiB/5.36 MiB
# litellm    ------------------------------ 5.12 MiB/6.43 MiB
# onnxruntime ------------------------------ 5.20 MiB/15.26 MiB
# uv         ------------------------------ 5.09 MiB/16.10 MiB
# ⠇ Preparing packages... (64/74)
# pytz       ------------------------------ 440.56 KiB/496.10 KiB
# jedi       ------------------------------ 488.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.34 MiB/1.90 MiB
# pypdfium2  ------------------------------ 1.00 MiB/2.74 MiB
# pyright    ------------------------------ 2.19 MiB/5.33 MiB
# litellm    ------------------------------ 5.38 MiB/6.43 MiB
# onnxruntime ------------------------------ 5.59 MiB/15.26 MiB
# uv         ------------------------------ 5.52 MiB/16.10 MiB
# ⠇ Preparing packages... (64/74)
# pytz       ------------------------------ 440.56 KiB/496.10 KiB
# jedi       ------------------------------ 488.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.34 MiB/1.90 MiB
# pypdfium2  ------------------------------ 1.00 MiB/2.74 MiB
# pyright    ------------------------------ 2.19 MiB/5.33 MiB
# litellm    ------------------------------ 5.43 MiB/6.43 MiB
# onnxruntime ------------------------------ 5.60 MiB/15.26 MiB
# uv         ------------------------------ 5.52 MiB/16.10 MiB
# ⠇ Preparing packages... (64/74)
# jedi       ------------------------------ 504.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.34 MiB/1.90 MiB
# pypdfium2  ------------------------------ 1.00 MiB/2.74 MiB
# pyright    ------------------------------ 2.19 MiB/5.33 MiB
# litellm    ------------------------------ 5.46 MiB/6.43 MiB
# onnxruntime ------------------------------ 5.87 MiB/15.26 MiB
# uv         ------------------------------ 5.80 MiB/16.10 MiB
# ⠇ Preparing packages... (64/74)
# jedi       ------------------------------ 520.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.40 MiB/1.90 MiB
# pypdfium2  ------------------------------ 1.00 MiB/2.74 MiB
# pyright    ------------------------------ 2.19 MiB/5.33 MiB
# litellm    ------------------------------ 5.77 MiB/6.43 MiB
# onnxruntime ------------------------------ 6.13 MiB/15.26 MiB
# uv         ------------------------------ 6.08 MiB/16.10 MiB
# ⠋ Preparing packages... (66/74)
# jedi       ------------------------------ 536.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# pypdfium2  ------------------------------ 1.31 MiB/2.74 MiB
# pyright    ------------------------------ 2.20 MiB/5.33 MiB
# litellm    ------------------------------ 5.87 MiB/6.43 MiB
# onnxruntime ------------------------------ 6.77 MiB/15.26 MiB
# uv         ------------------------------ 6.61 MiB/16.10 MiB
# ⠋ Preparing packages... (66/74)
# jedi       ------------------------------ 552.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.48 MiB/1.90 MiB
# pypdfium2  ------------------------------ 1.81 MiB/2.74 MiB
# pyright    ------------------------------ 2.20 MiB/5.33 MiB
# litellm    ------------------------------ 5.90 MiB/6.43 MiB
# onnxruntime ------------------------------ 7.16 MiB/15.26 MiB
# uv         ------------------------------ 7.22 MiB/16.10 MiB
# ⠋ Preparing packages... (66/74)
# jedi       ------------------------------ 552.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.51 MiB/1.90 MiB
# pypdfium2  ------------------------------ 2.28 MiB/2.74 MiB
# pyright    ------------------------------ 2.22 MiB/5.33 MiB
# litellm    ------------------------------ 5.91 MiB/6.43 MiB
# onnxruntime ------------------------------ 7.82 MiB/15.26 MiB
# uv         ------------------------------ 7.73 MiB/16.10 MiB
# ⠋ Preparing packages... (66/74)
# jedi       ------------------------------ 552.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.53 MiB/1.90 MiB
# pypdfium2  ------------------------------ 2.70 MiB/2.74 MiB
# pyright    ------------------------------ 2.24 MiB/5.33 MiB
# litellm    ------------------------------ 5.93 MiB/6.43 MiB
# onnxruntime ------------------------------ 8.36 MiB/15.26 MiB
# uv         ------------------------------ 8.00 MiB/16.10 MiB
# ⠙ Preparing packages... (66/74)
# jedi       ------------------------------ 568.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.56 MiB/1.90 MiB
# pypdfium2  ------------------------------ 2.74 MiB/2.74 MiB
# pyright    ------------------------------ 2.24 MiB/5.33 MiB
# litellm    ------------------------------ 5.95 MiB/6.43 MiB
# onnxruntime ------------------------------ 9.31 MiB/15.26 MiB
# uv         ------------------------------ 8.00 MiB/16.10 MiB
# ⠙ Preparing packages... (66/74)
# jedi       ------------------------------ 568.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.56 MiB/1.90 MiB
# pyright    ------------------------------ 2.24 MiB/5.33 MiB
# litellm    ------------------------------ 5.96 MiB/6.43 MiB
# onnxruntime ------------------------------ 9.68 MiB/15.26 MiB
# uv         ------------------------------ 8.00 MiB/16.10 MiB
# ⠙ Preparing packages... (66/74)
# jedi       ------------------------------ 568.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.59 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.02 MiB/6.43 MiB
# onnxruntime ------------------------------ 10.29 MiB/15.26 MiB
# uv         ------------------------------ 8.59 MiB/16.10 MiB
# ⠙ Preparing packages... (66/74)
# jedi       ------------------------------ 584.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.60 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.06 MiB/6.43 MiB
# onnxruntime ------------------------------ 11.25 MiB/15.26 MiB
# uv         ------------------------------ 9.50 MiB/16.10 MiB
# ⠙ Preparing packages... (66/74)
# jedi       ------------------------------ 600.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.60 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.06 MiB/6.43 MiB
# onnxruntime ------------------------------ 11.98 MiB/15.26 MiB
# uv         ------------------------------ 10.18 MiB/16.10 MiB
# ⠹ Preparing packages... (67/74)
# jedi       ------------------------------ 600.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.62 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.12 MiB/6.43 MiB
# onnxruntime ------------------------------ 12.64 MiB/15.26 MiB
# uv         ------------------------------ 10.98 MiB/16.10 MiB
# ⠹ Preparing packages... (67/74)
# jedi       ------------------------------ 616.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.62 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.17 MiB/6.43 MiB
# onnxruntime ------------------------------ 13.48 MiB/15.26 MiB
# uv         ------------------------------ 11.96 MiB/16.10 MiB
# ⠹ Preparing packages... (67/74)
# jedi       ------------------------------ 616.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.64 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.17 MiB/6.43 MiB
# onnxruntime ------------------------------ 13.93 MiB/15.26 MiB
# uv         ------------------------------ 12.26 MiB/16.10 MiB
# ⠹ Preparing packages... (67/74)
# jedi       ------------------------------ 616.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.65 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.23 MiB/6.43 MiB
# onnxruntime ------------------------------ 14.24 MiB/15.26 MiB
# uv         ------------------------------ 12.46 MiB/16.10 MiB
# ⠸ Preparing packages... (67/74)
# jedi       ------------------------------ 616.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.65 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.25 MiB/6.43 MiB
# onnxruntime ------------------------------ 14.48 MiB/15.26 MiB
# uv         ------------------------------ 12.81 MiB/16.10 MiB
# ⠸ Preparing packages... (67/74)
# jedi       ------------------------------ 616.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.70 MiB/1.90 MiB
# pyright    ------------------------------ 2.25 MiB/5.33 MiB
# litellm    ------------------------------ 6.26 MiB/6.43 MiB
# onnxruntime ------------------------------ 14.51 MiB/15.26 MiB
# uv         ------------------------------ 13.59 MiB/16.10 MiB
# ⠸ Preparing packages... (67/74)
# jedi       ------------------------------ 632.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.71 MiB/1.90 MiB
# pyright    ------------------------------ 2.26 MiB/5.33 MiB
# litellm    ------------------------------ 6.26 MiB/6.43 MiB
# onnxruntime ------------------------------ 14.62 MiB/15.26 MiB
# uv         ------------------------------ 14.11 MiB/16.10 MiB
# ⠸ Preparing packages... (67/74)
# jedi       ------------------------------ 632.56 KiB/1.50 MiB
# kubernetes ------------------------------ 1.73 MiB/1.90 MiB
# pyright    ------------------------------ 2.28 MiB/5.33 MiB
# litellm    ------------------------------ 6.28 MiB/6.43 MiB
# onnxruntime ------------------------------ 14.62 MiB/15.26 MiB
# uv         ------------------------------ 14.91 MiB/16.10 MiB
# ⠸ Preparing packages... (67/74)
# jedi       ------------------------------ 632.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.28 MiB/5.33 MiB
# litellm    ------------------------------ 6.30 MiB/6.43 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# uv         ------------------------------ 15.19 MiB/16.10 MiB
# ⠼ Preparing packages... (67/74)
# jedi       ------------------------------ 648.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.28 MiB/5.33 MiB
# litellm    ------------------------------ 6.30 MiB/6.43 MiB
# onnxruntime ------------------------------ 14.65 MiB/15.26 MiB
# uv         ------------------------------ 15.42 MiB/16.10 MiB
# ⠼ Preparing packages... (67/74)
# jedi       ------------------------------ 664.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.30 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.72 MiB/15.26 MiB
# uv         ------------------------------ 15.42 MiB/16.10 MiB
# ⠼ Preparing packages... (67/74)
# jedi       ------------------------------ 664.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.30 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.72 MiB/15.26 MiB
# uv         ------------------------------ 15.83 MiB/16.10 MiB
# ⠼ Preparing packages... (67/74)
# jedi       ------------------------------ 664.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.31 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.72 MiB/15.26 MiB
# uv         ------------------------------ 16.10 MiB/16.10 MiB
# ⠼ Preparing packages... (67/74)
# jedi       ------------------------------ 664.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.31 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.72 MiB/15.26 MiB
# uv         ------------------------------ 16.10 MiB/16.10 MiB
# ⠼ Preparing packages... (67/74)
# jedi       ------------------------------ 664.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.31 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.72 MiB/15.26 MiB
# ⠴ Preparing packages... (69/74)
# jedi       ------------------------------ 680.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.34 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.73 MiB/15.26 MiB
# ⠴ Preparing packages... (69/74)
# jedi       ------------------------------ 696.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.34 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.75 MiB/15.26 MiB
# ⠴ Preparing packages... (69/74)
# jedi       ------------------------------ 728.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.39 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.75 MiB/15.26 MiB
# ⠴ Preparing packages... (69/74)
# jedi       ------------------------------ 776.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.42 MiB/5.33 MiB
# onnxruntime ------------------------------ 14.82 MiB/15.26 MiB
# ⠦ Preparing packages... (70/74)
# jedi       ------------------------------ 776.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.45 MiB/5.33 MiB
# onnxruntime ------------------------------ 15.16 MiB/15.26 MiB
# ⠦ Preparing packages... (70/74)
# jedi       ------------------------------ 776.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.45 MiB/5.33 MiB
# ⠦ Preparing packages... (70/74)
# jedi       ------------------------------ 824.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.48 MiB/5.33 MiB
# ⠦ Preparing packages... (70/74)
# jedi       ------------------------------ 840.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.48 MiB/5.33 MiB
# ⠦ Preparing packages... (70/74)
# jedi       ------------------------------ 840.56 KiB/1.50 MiB
# pyright    ------------------------------ 2.48 MiB/5.33 MiB
# ⠦ Preparing packages... (70/74)
# jedi       ------------------------------ 840.56 KiB/1.50 MiB
# ⠧ Preparing packages... (72/74)
# jedi       ------------------------------ 872.56 KiB/1.50 MiB
# ⠧ Preparing packages... (72/74)
# jedi       ------------------------------ 995.56 KiB/1.50 MiB
# ⠧ Preparing packages... (72/74)
# jedi       ------------------------------ 1.08 MiB/1.50 MiB
# ⠧ Preparing packages... (72/74)
# jedi       ------------------------------ 1.20 MiB/1.50 MiB
# ⠇ Preparing packages... (72/74)
# ⠇ Preparing packages... (72/74)
# ⠇ Preparing packages... (72/74)
# ⠇ Preparing packages... (72/74)
# ⠇ Preparing packages... (72/74)
# ⠋ Preparing packages... (73/74)
# ⠋ Preparing packages... (73/74)
# ⠋ Preparing packages... (73/74)
# ⠋ Preparing packages... (73/74)
# ⠙ Preparing packages... (73/74)
# ⠙ Preparing packages... (73/74)
# ⠙ Preparing packages... (73/74)
# Prepared 74 packages in 5.57s
# Uninstalled 4 packages in 50ms
# Installed 74 packages in 489ms
#  + alembic==1.15.2
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + auth0-python==4.9.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + build==1.2.2.post1
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + cohere==5.15.0
#  + coloredlogs==15.0.1
#  + crewai==0.114.0
#  + crewai-tools==0.40.1
#  + deprecation==2.1.0
#  + docker==7.1.0
#  + durationpy==0.9
#  + embedchain==0.1.128
#  + fastavro==1.10.0
#  + gptcache==0.1.44
#  + grpcio-tools==1.71.0
#  + httptools==0.6.4
#  - httpx==0.28.1
#  + httpx==0.27.2
#  + humanfriendly==10.0
#  + instructor==1.7.9
#  + jedi==0.19.2
#  - jiter==0.9.0
#  + jiter==0.8.2
#  + json-repair==0.41.1
#  + json5==0.12.0
#  + jsonref==1.1.0
#  + kubernetes==32.0.1
#  + lancedb==0.21.2
#  + langchain-cohere==0.3.5
#  + langchain-experimental==0.3.5rc1
#  + langchain-openai==0.2.14
#  + litellm==1.60.2
#  + mako==1.3.10
#  + mem0ai==0.1.92
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + nodeenv==1.9.1
#  + onnxruntime==1.21.1
#  + opentelemetry-exporter-otlp-proto-common==1.32.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.32.1
#  + opentelemetry-exporter-otlp-proto-http==1.32.1
#  + opentelemetry-instrumentation==0.53b1
#  + opentelemetry-instrumentation-asgi==0.53b1
#  + opentelemetry-instrumentation-fastapi==0.53b1
#  + opentelemetry-proto==1.32.1
#  + opentelemetry-util-http==0.53b1
#  + overrides==7.7.0
#  + pdfminer-six==20250327
#  + pdfplumber==0.11.6
#  + portalocker==2.10.1
#  + posthog==3.25.0
#  + psycopg2-binary==2.9.10
#  + pypdf==5.4.0
#  + pypdfium2==5.0.0b1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.399
#  + pysbd==0.3.4
#  + pytube==15.0.0
#  - pytz==2025.2
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + qdrant-client==1.13.3
#  + schema==0.7.7
#  + tiktoken==0.9.0
#  - tokenizers==0.21.1
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + types-requests==2.32.0.20250328
#  + uv==0.6.14
#  + uvloop==0.21.0
#  + watchfiles==1.0.5

# %%
# Set up DALL-E image creation tool from CrewAI

from google.adk.tools.crewai_tool import CrewaiTool
from crewai_tools import DallETool

dalle_tool_instance = DallETool(model = "dall-e-3",
                       size = "1024x1024", # Create square image
                       quality = "hd", # Create HD image
                       n = 1) # Returns 1 image as a result

adk_dalle_tool = CrewaiTool(
    name = "DALLE_Image_Creation_Tool",
    description = "Generates images using DALL-E.",
    tool = dalle_tool_instance,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:623: UserWarning: <built-in function callable> is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(

# %%
# Set up OpenAI API key

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

# %%
# Image Generation Agent
image_generation_agent = LlmAgent(
    name = "Image_Generation_Agent",
    model = GEMINI_MODEL,
    instruction = """
    You are an Image Generation AI.
    Generate an beautiful, minimalistic and attention grabbing image for the context provided in the session state with the key 'final_post'.
    It should visually represent the key insights of the final LinkedIn post.
    This image will be posted with this LinkedIn post.
    **Please avoid** using any text in the image.
    Return the URL of the infographic image in your response.
    """,
    description = "Generates image using DALL-E.",
    tools = [adk_dalle_tool],
    output_key = "image_url"
)

# %%
from google.adk.agents.sequential_agent import SequentialAgent

linkedin_content_creation_pipeline = SequentialAgent(
    name="LinkedIn_Content_Creation_Pipeline",
    sub_agents=[parallel_web_research_agent, writer_agent, seo_optimizer_agent, final_draft_writing_agent, image_generation_agent]
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-25-7d0780f610a8> in <cell line: 0>()
#       1 from google.adk.agents.sequential_agent import SequentialAgent
#       2
# ----> 3 linkedin_content_creation_pipeline = SequentialAgent(
#       4     name="LinkedIn_Content_Creation_Pipeline",
#       5     sub_agents=[parallel_web_research_agent, writer_agent, seo_optimizer_agent, final_draft_writing_agent, image_generation_agent]
#
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py in __init__(self, **data)
#     251         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252         __tracebackhide__ = True
# --> 253         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254         if self is not validated_self:
#     255             warnings.warn(
#
# ValidationError: 1 validation error for SequentialAgent
#   Value error, Agent `Parallel_Web_Research_Agent` already has a parent agent, current parent: `LinkedIn_Content_Creation_Pipeline`, trying to add: `LinkedIn_Content_Creation_Pipeline` [type=value_error, input_value={'name': 'LinkedIn_Conten...er_tool_callback=None)]}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error

# %%
#Set up constants
APP_NAME = "linkedin_content_creation_app"
USER_ID = "ashish_bamania"
SESSION_ID = "content_session_01"

# %%
from google.adk.sessions import InMemorySessionService

# Set up Session
session_service = InMemorySessionService()
session = session_service.create_session(app_name=APP_NAME, user_id=USER_ID, session_id=SESSION_ID)

# %%
from google.adk.runners import Runner  # 例: 正しいパスに修正

# %%
# Set up Runner
runner = Runner(agent=linkedin_content_creation_pipeline, app_name=APP_NAME, session_service=session_service)

# %%
from google.genai import types

def call_agent(query):
    '''
    Helper function to call the agent with a query.
    '''
    content = types.Content(role='user', parts=[types.Part(text=query)])
    events = runner.run(user_id=USER_ID, session_id=SESSION_ID, new_message=content)

    for event in events:
        if event.is_final_response():
            author = event.author
            final_response = event.content.parts[0].text
            print(f"{author} Response:\n{final_response}\n")

# %%
call_agent("How to master patience")
