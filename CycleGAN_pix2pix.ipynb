# %% [markdown]
# <a href="https://colab.research.google.com/github/tthogho1/CompareImage/blob/main/CycleGAN_pix2pix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2443, done.
# remote: Total 2443 (delta 0), reused 0 (delta 0), pack-reused 2443
# Receiving objects: 100% (2443/2443), 8.13 MiB | 21.46 MiB/s, done.
# Resolving deltas: 100% (1570/1570), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 22.3 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 140 kB 47.4 MB/s
# ...
#      |████████████████████████████████| 180 kB 44.8 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=443c1c6ee610d0ca699321efbc5b8b99576c2c720f62dcc11e9344ba9d72ab51
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=1e4dbb039000aeeac23997215d7c7931189000c3ccf0713ff4d60dc4d5073120
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...

# %%
# !bash ./datasets/download_pix2pix_dataset.sh facades
# Out:
# Specified [facades]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-11-19 08:54:58--  http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/facades.tar.gz
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30168306 (29M) [application/x-gzip]
# Saving to: ‘./datasets/facades.tar.gz’
#
# ./datasets/facades. 100%[===================>]  28.77M  1.71MB/s    in 17s
#
# 2021-11-19 08:55:15 (1.72 MB/s) - ‘./datasets/facades.tar.gz’ saved [30168306/30168306]
#
# facades/
# facades/test/
# facades/test/27.jpg
# facades/test/5.jpg
# facades/test/72.jpg
# facades/test/1.jpg
# facades/test/10.jpg
# facades/test/100.jpg
# facades/test/101.jpg
# facades/test/102.jpg
# facades/test/103.jpg
# facades/test/104.jpg
# facades/test/105.jpg
# ...

# %%
# !bash ./scripts/download_pix2pix_model.sh facades_label2photo
# Out:
# Note: available models are edges2shoes, sat2map, map2sat, facades_label2photo, and day2night
# Specified [facades_label2photo]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-11-19 08:55:24--  http://efrosgans.eecs.berkeley.edu/pix2pix/models-pytorch/facades_label2photo.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 217704720 (208M)
# Saving to: ‘./checkpoints/facades_label2photo_pretrained/latest_net_G.pth’
#
# ./checkpoints/facad 100%[===================>] 207.62M  2.70MB/s    in 80s
#
# 2021-11-19 08:56:43 (2.61 MB/s) - ‘./checkpoints/facades_label2photo_pretrained/latest_net_G.pth’ saved [217704720/217704720]

# %%
# !python train.py --dataroot ./datasets/facades --name facades_pix2pix --model pix2pix --direction BtoA --us
# Out:
# wandb: Run history:
# wandb:   D_fake ▇▄▅▅▄▄▃▁▂█▆▂▄▁▁
# wandb:   D_real ▅▁▁▂▁▂▄▆▆▃▁▄▂▂█
# wandb:    G_GAN ▂▆▇▆█▆▃▆▂▁▅▂▄▅▃
# wandb:     G_L1 ▄█▅▄▆▄▃▄▂▁▇▅▆▃▃
# wandb:
# wandb: Run summary:
# wandb:   D_fake 0.04232
# wandb:   D_real 1.28901
# wandb:    G_GAN 1.6688
# wandb:     G_L1 28.45612
# wandb:
# wandb: Synced 5 W&B file(s), 12 media file(s), 12 artifact file(s) and 0 other file(s)
# wandb: Synced facades_pix2pix: https://wandb.ai/tthogho1/CycleGAN-and-pix2pix/runs/17ltlh65
# wandb: Find logs at: ./wandb/run-20211119_093249-17ltlh65/logs/debug.log
# wandb:

# %%
! add-apt-repository ppa:graphics-drivers/ppa
! apt update
! apt install nvidia-384 nvidia-384-dev
! apt-get install g++ freeglut3-dev build-essential libx11-dev libxmu-dev libxi-dev libglu1-mesa libglu1-mesa-dev
# Out:
#  Fresh drivers from upstream, currently shipping Nvidia.
#
# ## Current Status
#
# Current long-lived branch release: `nvidia-430` (430.40)
# Dropped support for Fermi series (https://nvidia.custhelp.com/app/answers/detail/a_id/4656)
#
# Old long-lived branch release: `nvidia-390` (390.129)
#
# For GF1xx GPUs use `nvidia-390` (390.129)
# For G8x, G9x and GT2xx GPUs use `nvidia-340` (340.107)
# For NV4x and G7x GPUs use `nvidia-304` (304.137) End-Of-Life!
#
# Support timeframes for Unix legacy GPU releases:
# https://nvidia.custhelp.com/app/answers/detail/a_id/3142
#
# ## What we're working on right now:
#
# - Normal driver updates
# - Help Wanted: Mesa Updates for Intel/AMD users, ping us if you want to help do this work, we're shorthanded.
#
# ## WARNINGS:
#
# This PPA is currently in testing, you should be experienced with packaging before you dive in here:
#
# Volunteers welcome!
#
# ### How you can help:
#
# ## Install PTS and benchmark your gear:
#
# ...

# %%
# !nvidia-smi
# Out:
# Fri Nov 19 08:53:28 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
